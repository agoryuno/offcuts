# %%
from itertools import islice

import pandas as pd
import numpy as np

from openpyxl import load_workbook

DATA_FILE = "задание_dsc339a3a1-1431-4382-b898-9b0a9eef77e2.xlsx"

# %%
def load_data(sheetnum,
              fname=DATA_FILE, 
              col_names=("name", "gender", "document", "country"),
             ):
    wb = load_workbook(filename=DATA_FILE)
    ws = wb.worksheets[sheetnum]

    data = pd.DataFrame(islice(ws.values,1, None))
    data.columns = col_names
    return data

def split_name(df):
    data = df.copy()
    names = data["name"].str.split("\s+", expand=True)
    col_names = [f"name{i}" for i in names.columns]
    names.columns = col_names
    data.loc[:, col_names] = names[col_names]
    return data

# %% [markdown]
#  Загрузим данные и разделим имена на части.

# %%
fact = load_data(1)
test = load_data(2)
fact_data = split_name(fact)
test_data = split_name(test)

# %% [markdown]
# ## Присвоение признака пола

# %% [markdown]
# Сколько уникальных фамилий в "фактическом" датасете:

# %%
fact_data["name0"].unique().shape[0]
# Out:
# 5895

# %% [markdown]
# Сколько фамилий в "фактическом" датасете принадлежат людям обоих полов:

# %%
a = fact_data[["name0", "gender"]].drop_duplicates()
a = a.groupby("name0").count().reset_index()
twin_gender = a[a["gender"]>1]
len(twin_gender.index)
# Out:
# 218

# %% [markdown]
# Присвоить признак пола по имени:

# %%
def match_gender(fact_data, test_data):
    columns = [c for c in fact_data.columns if c[:len("name")] == "name" and len(c)>len("name")]
    keys = ["name", "gender"] + columns
    matched = pd.DataFrame(dict(zip(keys, [[] for i in range(len(keys))])))
    for i,c in enumerate(columns):
        a = fact_data[[c, "gender"]].drop_duplicates().dropna()
        b = a.groupby(c).count().reset_index()
        twin_list = b[b["gender"]>1][c].tolist()
        lookup = a[~a[c].isin(twin_list)]
        idx = test_data[c].isin(a[c]) & \
                          (~test_data[c].isin(twin_list))
        if len(matched.index) > 0:
            for j in range(i):
                idx = idx & (~test_data[f"name{j}"].isin(matched[f"name{j}"]))
        combo = test_data[idx][["name"] + columns].drop_duplicates()
        res = pd.merge(combo, lookup, on=c)
        matched = pd.concat([matched, res])
    return matched

matched_gender = match_gender(fact_data, test_data)

# %% [markdown]
# У части тестовых записей отсутствуют аналоги в фактических данных

# %%
a = test_data[["name", "name0", "name1", "name2", "name3", "name4", "name5"]].drop_duplicates()
missing = a[~a["name"].isin(matched_gender["name"])]
missing
# Out:
#                                       name        name0     name1  \
# 12                      АБДАЗИЗОВА ОМУРКАН   АБДАЗИЗОВА   ОМУРКАН
# 17                       АБДИЛАМИТОВ МУМИН  АБДИЛАМИТОВ     МУМИН
# 20                   АБДИНАЗИМ КЫЗЫ МУНАИМ    АБДИНАЗИМ      КЫЗЫ
# 26    АБДУГАНИЕВА МАЛОХАТ МУФТОХИДДИН КИЗИ  АБДУГАНИЕВА   МАЛОХАТ
# 43       АБДУМАНАБОВ МУРАДЖОН СОВОНКУЛОВИЧ  АБДУМАНАБОВ  МУРАДЖОН
# ...                                    ...          ...       ...
# 2431             ЩАННИКОВА НАТАЛЬЯ ЮРЬЕВНА    ЩАННИКОВА   НАТАЛЬЯ
# 2460          ЭРНАЗАРОВ САФАРАЛИ ГАЙИПОВИЧ    ЭРНАЗАРОВ  САФАРАЛИ
# 2461       ЭРНАФАСОВ ЭШМУРОД КУРОКБОЙ УГЛИ    ЭРНАФАСОВ   ЭШМУРОД
# 2464                    ЭСЕНБАЕВА ГУЛСИНАЙ    ЭСЕНБАЕВА  ГУЛСИНАЙ
# 2498              ЯХЬЯЕВА САНИЯ ОРУДЖ КЫЗЫ      ЯХЬЯЕВА     САНИЯ
#
#              name2 name3 name4 name5
# 12            None  None  None  None
# 17            None  None  None  None
# 20          МУНАИМ  None  None  None
# 26     МУФТОХИДДИН  КИЗИ  None  None
# 43    СОВОНКУЛОВИЧ  None  None  None
# ...            ...   ...   ...   ...
# 2431       ЮРЬЕВНА  None  None  None
# 2460     ГАЙИПОВИЧ  None  None  None
# 2461      КУРОКБОЙ  УГЛИ  None  None
# 2464          None  None  None  None
# 2498         ОРУДЖ  КЫЗЫ  None  None
#
# [247 rows x 7 columns]

# %% [markdown]
# Попробуем найти близкие аналоги по косинусному расстоянию:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def match_cosine(fact_data, test_data):
    matching_vec = fact_data["name"].unique()
    tfidf_vectorizer = TfidfVectorizer()
    sparse_matrix = tfidf_vectorizer.fit_transform(matching_vec)
    term_matrix = sparse_matrix.toarray()
    
    def _(to_match):
        match_trf = tfidf_vectorizer.transform([to_match]).toarray()
        match_cosine = cosine_similarity(term_matrix, match_trf)
        return (to_match, matching_vec[np.argmax(match_cosine), match_cosine])
    
    return [_(name) for name in test_data["name"]]

# %%
a = list(zip(*match_cosine(fact_data, missing)))
cos_matched = pd.DataFrame({"test_name" : a[0], "fact_name" : a[1]})
b = fact_data.loc[fact_data["name"].isin(a[1]), ["name", "gender"]].drop_duplicates()
b = b.rename(columns={"name" : "fact_name"})
res = pd.merge(cos_matched, b, on="fact_name").drop(columns="fact_name")
res = res.rename(columns={"test_name" : "name"})

# %%
full_match = pd.concat([matched_gender[["name", "gender"]], res])

# %% [markdown]
# Проверим результат на базовую вменяемость. Поскольку таких случаев не слишком много, мы можем проверить их "на глаз" и если исключений не обнаружим, то заменим пол на противоположный для всех выявленных записей.

# %%
idx = (full_match["name"].str.contains(r"ОВНА\b") & (full_match["gender"] == "М")) | \
    (full_match["name"].str.contains(r"ОВИЧ\b") & (full_match["gender"] == "Ж"))
full_match[idx]
# Out:
#                                         name gender
# 44                     АДАМЯН РИТА ЗАВЕНОВНА      М
# 101                    АМОЯН АРАМ САРГИСОВИЧ      Ж
# 124                 АТАБЕКЯН ДЖИВАН НВЕРОВИЧ      Ж
# 174                 БАКОЯН АНТАРАМ ГАГИКОВНА      М
# 193                     БИЛЫК РОМАН ОДИЛОВИЧ      Ж
# 203            БОНДАРЬ СВЕТЛАНА ПОЛИКАРПОВНА      М
# 233                 ГАРИБЯН АРЦВИК РАФИКОВНА      М
# 259                ГЕВОНДЯН АСТГИК АМАЯКОВНА      М
# 325           ДЬЯЧЕНКО ВАЛЕРИЯ АЛЕКСАНДРОВНА      М
# 340      ЖЕНИШБЕК КЫЗЫ МИЛАННА АЛЕКСАНДРОВНА      М
# 371                 ЗОГРАБЯН ЕРАНУИ ВРЕЖОВНА      М
# 388            ИВАЩУК АЛЕКСАНДР ВЛАДИМИРОВИЧ      Ж
# 424    КАНАТБЕК КЫЗЫ ДИЛНОЗАХОН АЛМАНБЕТОВНА      М
# 458                  КОТЕНКО ДЖАВИД ОЛЕГОВИЧ      Ж
# 491             ЛОГВИНЕНКО МИХАИЛ ВИКТОРОВИЧ      Ж
# 547          МАНУЧАРЯН ЭСМИРАЛЬДА ГАРНИКОВНА      М
# 548                МАРАБЯН ВАРДУШ САРКИСОВНА      М
# 618                МХИТАРЯН НАИРА РУСТАМОВНА      М
# 630              НАЛБАНДЯН ХАНУМ МАКЕДОНОВНА      М
# 647              ОВАННИСЯН АНАИТ АРАМАИСОВНА      М
# 649                ОГАНИСЯН МЕЛИНЕ ВАНИКОВНА      М
# 720                  РУДЕНКО ГАЛИНА ПАВЛОВНА      М
# 770               СТЕПАНЕНКО КИРИЛЛ ИВАНОВИЧ      Ж
# 772                   СТЕЦЮК РУСЛАН ПЕТРОВИЧ      Ж
# 800         ТОШМАМАТОВ БАХАДИР ТУРСУНКУЛОВНА      М
# 814                  УНАНЯН НАИРА ГАРНИКОВНА      М
# 826               ФРАНГУЛЯН ЛИАНА МОВСЕСОВНА      М
# 849                     ХАНЯН СРБУИ АКОБОВНА      М
# 859                ХЛГАТЯН ШОГИК ГАРЕГИНОВНА      М
# 873                   ХУДОЯН ВАГАН СЕРОБОВИЧ      Ж
# 906             ЩЕРБИНА НИКОЛАЙ ВЛАДИМИРОВИЧ      Ж
# 419               НАХАНОВИЧ МАРИЯ ЕВГЕНЬЕВНА      Ж
# 424        ТУРДУМАМАТОВА АНАР КУБАНЫЧБЕКОВНА      М
# 896               ИВАНОВИЧ САМИРА ВИКТОРОВНА      Ж
# 1118               ПАХОМОВА ЯН АЛЕКСАНДРОВНА      М
# 58                    ОВЕЯН ДАНИЕЛ ПАПИНОВИЧ      Ж
# 17                   АБОЯН ВИЛЕНА РАФАЭЛОВНА      М
# 18           АДИЛШАЕВА МУХАЕХОН МАХАММАДОВНА      М
# 24               АСКЕЕВА АЙТУНУК АСИЛБЕКОВНА      М
# 27               БАЗАРБАЕВА САЕРА ХОЛМАТОВНА      М
# 29                   БАРСАМЯН ЗАРУИ СААКОВНА      М
# 45           ИЗБОСАРОВА ДИЛРАБОХОН ЭРКИНОВНА      М
# 52              КАЛМАМАТОВА ИНАВАТ РАШИДОВНА      М
# 59          МАМИРЖАНОВА ГУЛСУН ГАЙРАТБЕКОВНА      М
# 74             ОРОКБАЕВА КАЛЫЙПА МАГАМЕТОВНА      М
# 78         РАИМБЕКОВА ЛУТФИЛЛАХАН АЯЗБЕКОВНА      М
# 80             САПАРБАЕВА ХУРЛИМАН КАРИМОВНА      М
# 83    САТИБОЛДИЕВА МАХБУБАХОН АЛЛАБЕРГАНОВНА      М
# 92                  УРИНОВА ХОСИЯТ ЗУФАРОВНА      М
# 96              ЧЫНКОЖО ШОИРАХОН ЖУМАДИЛОВНА      М
# 120                 АРСЕНЯН ОТАРИК ГУРАМОВИЧ      Ж
# 154                    ГРИГОРЯН АСЯ ВЛАСОВНА      М
# 179         КУМАРБЕК КЫЗЫ НАЗИРА БАХТИЯРОВНА      М
# 185            МАКЕНОВ УЛАРБЕК МАХМУДЖАНОВИЧ      Ж
# 207                ОГАНЯН СУСАННА МИХАЕЛОВНА      М
# 216              СААКЯН МАРДЖАНИК АРАРАТОВНА      М
# 221              САРУХАНЯН СЕМИОН МИГРАНОВИЧ      Ж
# 223                  СОГОЯН ЕЛИНА ГАМЛЕТОВНА      М

# %% [markdown]
# "ИВАНОВИЧ САМИРА ВИКТОРОВНА" явно определена правильно как женщина, что наводит нас на мысль о целесообразности дополнительного теста:

# %%
idx2 = (full_match["name"].str.contains(r"ОВНА\b") & full_match["name"].str.contains(r"ОВИЧ\b"))
full_match[idx2]
# Out:
#                            name gender
# 896  ИВАНОВИЧ САМИРА ВИКТОРОВНА      Ж

# %% [markdown]
# Похоже, что Самира Викторовна уникальна, поэтому ее мы исключаем, а для остальных заменяем пол на противоположный:

# %%
exceptions = full_match[idx].copy()
exceptions = exceptions.drop(exceptions[exceptions["name"]=="ИВАНОВИЧ САМИРА ВИКТОРОВНА"].index)
gen_flip = {"Ж" : "М", "М" : "Ж"}
flipped_gen = [gen_flip[gen] for gen in exceptions["gender"]]
exceptions.loc[:, "gender"] = flipped_gen

full_match.loc[full_match["name"].isin(exceptions["name"]), "gender"] = exceptions["gender"]

# %%
full_match
# Out:
#                              name gender
# 0        АБАСОВ РАШАД РАДЖАБ ОГЛЫ      М
# 1         АБАСОВА УЛЬЯНА ИГОРЕВНА      Ж
# 2      АББАСОВ ДЖЕЙХУН ДАВУД ОГЛЫ      М
# 3     АББАСОВ ДУНЯМИН МАХМУД ОГЛЫ      М
# 4        АББАСОВ ЕЛЬНУР АРИЗ ОГЛЫ      М
# ..                            ...    ...
# 242  ШАРИПОВ АБДИМАЛИК АЛИЖАНОВИЧ      М
# 243   ШИРАЛИЕВА СААДЕТ КАМИЛ КЫЗЫ      Ж
# 244     ЩАННИКОВА НАТАЛЬЯ ЮРЬЕВНА      Ж
# 245  ЭРНАЗАРОВ САФАРАЛИ ГАЙИПОВИЧ      М
# 246      ЯХЬЯЕВА САНИЯ ОРУДЖ КЫЗЫ      Ж
#
# [2500 rows x 2 columns]

# %% [markdown]
# ## Присвоение признака страны

# %% [markdown]
# Наличие уникальных схем номеров документа для стран в фактических данных позволяет нам присвоить страну некоторой части наблюдений в тестовых данных. Эти уникальные схемы:

# %%
# Find document patterns that are unique for a country
a = fact_data[["document", "country"]].drop_duplicates()
b = a.groupby(["document"]).count().reset_index()
unq_pat = b[b["country"]==1]
unq_doc_lookup = fact_data.loc[fact_data["document"].isin(unq_pat["document"]), ["document", "country"]].drop_duplicates()
unq_doc_lookup
# Out:
#            document      country
# 0          AP!!!!!!      АРМЕНИЯ
# 1         AB!!!!!!!   УЗБЕКИСТАН
# 2         СР!!!!!!!   УЗБЕКИСТАН
# 11       AZII!!!!!!  АЗЕРБАЙДЖАН
# 14        C!!!!!!!!  АЗЕРБАЙДЖАН
# ...             ...          ...
# 9281   PKGZAC!!!!!!     КИРГИЗИЯ
# 9341      CH!!!!!!!   УЗБЕКИСТАН
# 9397      !!!!!!!СО  АЗЕРБАЙДЖАН
# 9471  PUZBCB!!!!!!!   УЗБЕКИСТАН
# 9499      СГ!!!!!!!   УЗБЕКИСТАН
#
# [436 rows x 2 columns]

# %% [markdown]
# Присвоим национальность части тестовых наблюдений:

# %%
a = test_data.copy()
a = a.drop(columns="country")
doc_matched = pd.merge(a, unq_doc_lookup)
doc_matched
# Out:
#                                 name gender     document      name0     name1  \
# 0        АББАСОВ ЭЛЬФАГ ИБРАГИМ ОГЛЫ   None    P!!!!!!!!    АББАСОВ    ЭЛЬФАГ
# 1           АБГАРЯН ДИАНА АРКАДЬЕВНА   None     AR!!!!!!    АБГАРЯН     ДИАНА
# 2               АЙРОЯН ГЕВОРГ ЭДУАРД   None     AR!!!!!!     АЙРОЯН    ГЕВОРГ
# 3           АМРОЯН КАДЖИК ГЕВОРГОВИЧ   None     AR!!!!!!     АМРОЯН    КАДЖИК
# 4             АНИСЯН АНАИТ КОРЮНОВНА   None     AR!!!!!!     АНИСЯН     АНАИТ
# ..                               ...    ...          ...        ...       ...
# 563  ЧЕРШУКОВА АНЖЕЛИКА ВЛАДИМИРОВНА   None   АВ!!!!!!!!  ЧЕРШУКОВА  АНЖЕЛИКА
# 564          ШИТОВА ОЛЬГА ВАСИЛЬЕВНА   None     ET!!!!!!     ШИТОВА     ОЛЬГА
# 565     ЭВАЙЗОВ АДИЛ ТАНРЫВЕРДИ ОГЛЫ   None    CO!!!!!!!    ЭВАЙЗОВ      АДИЛ
# 566      ЭЙВАЗОВА СААДАТ ЭЛЬЧИН КЫЗЫ   None  VIIМЮ!!!!!!   ЭЙВАЗОВА    СААДАТ
# 567                     ЮДИНА ПОЛИНА   None   I-ВВ!!!!!!      ЮДИНА    ПОЛИНА
#
#             name2 name3 name4 name5      country
# 0         ИБРАГИМ  ОГЛЫ  None  None       РОССИЯ
# 1      АРКАДЬЕВНА  None  None  None      АРМЕНИЯ
# 2          ЭДУАРД  None  None  None      АРМЕНИЯ
# 3      ГЕВОРГОВИЧ  None  None  None      АРМЕНИЯ
# 4       КОРЮНОВНА  None  None  None      АРМЕНИЯ
# ..            ...   ...   ...   ...          ...
# 563  ВЛАДИМИРОВНА  None  None  None   УЗБЕКИСТАН
# 564    ВАСИЛЬЕВНА  None  None  None      УКРАИНА
# 565    ТАНРЫВЕРДИ  ОГЛЫ  None  None  АЗЕРБАЙДЖАН
# 566        ЭЛЬЧИН  КЫЗЫ  None  None       РОССИЯ
# 567          None  None  None  None      УКРАИНА
#
# [568 rows x 10 columns]

# %%
len(test_data.index) - len(doc_matched.index)
# Out:
# 1932

# %%
# find the closest match for test name in each country group
from difflib import SequenceMatcher
from tqdm import tqdm


def similarity(word1, word2):
    return SequenceMatcher(None, word1, word2).ratio()

def country_matcher(to_match, method="max"):
    assert method in ("max", "mean"), f"Unknown method: {method}"
    meth = {"max" : np.max, "mean" : np.mean}[method]
    def _(country_grp):
        res = {"name0" : [], "similarity" : []}
        for name in tqdm(to_match):
            sims = [similarity(name, name2) for name2 in country_grp["name0"] if name != name2]
            res["name0"].append(name)
            res["similarity"].append(meth(sims))
        df = pd.DataFrame(res)
        return df
    return _
    
a = fact_data[["name0", "country"]].copy().dropna()
b = test_data.loc[~test_data["name"].isin(doc_matched["name"]), ["name0", "country"]].copy()

sims = a[["name0", "country"]].groupby("country").apply(country_matcher(b["name0"]))
# Out:
# 100%|███████████████████████████████████████| 1932/1932 [01:43<00:00, 18.58it/s]
#   0%|                                          | 5/1932 [00:00<01:40, 19.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_213199/2875093245.py in <module>
#      23 b = test_data.loc[~test_data["name"].isin(doc_matched["name"]), ["name0", "country"]].copy()
#      24
# ---> 25 sims = a[["name0", "country"]].groupby("country").apply(country_matcher(b["name0"]))
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1421         with option_context("mode.chained_assignment", None):
#    1422             try:
# -> 1423                 result = self._python_apply_general(f, self._selected_obj)
#    1424             except TypeError:
#    1425                 # gh-20949
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same)
#    1462             data after applying f
#    1463         """
# -> 1464         values, mutated = self.grouper.apply(f, data, self.axis)
#    1465
#    1466         if not_indexed_same is None:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     759             # group might be modified
#     760             group_axes = group.axes
# --> 761             res = f(group)
#     762             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763                 mutated = True
#
# /tmp/ipykernel_213199/2875093245.py in _(country_grp)
#      13         res = {"name0" : [], "similarity" : []}
#      14         for name in tqdm(to_match):
# ---> 15             sims = [similarity(name, name2) for name2 in country_grp["name0"] if name != name2]
#      16             res["name0"].append(name)
#      17             res["similarity"].append(meth(sims))
#
# /tmp/ipykernel_213199/2875093245.py in <listcomp>(.0)
#      13         res = {"name0" : [], "similarity" : []}
#      14         for name in tqdm(to_match):
# ---> 15             sims = [similarity(name, name2) for name2 in country_grp["name0"] if name != name2]
#      16             res["name0"].append(name)
#      17             res["similarity"].append(meth(sims))
#
# /tmp/ipykernel_213199/2875093245.py in similarity(word1, word2)
#       5
#       6 def similarity(word1, word2):
# ----> 7     return SequenceMatcher(None, word1, word2).ratio()
#       8
#       9 def country_matcher(to_match, method="max"):
#
# /usr/lib/python3.10/difflib.py in ratio(self)
#     617         """
#     618
# --> 619         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     621
#
# /usr/lib/python3.10/difflib.py in get_matching_blocks(self)
#     484                 i1, j1, k1 = i2, j2, k2
#     485         if k1:
# --> 486             non_adjacent.append((i1, j1, k1))
#     487
#     488         non_adjacent.append( (la, lb, 0) )
#
# KeyboardInterrupt:

# %%
sims.reset_index()
# Out:
#            country  level_1    name0  similarity
# 0      АЗЕРБАЙДЖАН        0   АБАСОВ    0.923077
# 1      АЗЕРБАЙДЖАН        1  АБАСОВА    0.933333
# 2      АЗЕРБАЙДЖАН        2  АББАСОВ    0.933333
# 3      АЗЕРБАЙДЖАН        3  АББАСОВ    0.933333
# 4      АЗЕРБАЙДЖАН        4  АББАСОВ    0.933333
# ...            ...      ...      ...         ...
# 11587      УКРАИНА     1927  ЯКУБОВА    0.750000
# 11588      УКРАИНА     1928  ЯКУШЕВА    0.714286
# 11589      УКРАИНА     1929     ЯСИК    0.600000
# 11590      УКРАИНА     1930  ЯХЬЯЕВА    0.545455
# 11591      УКРАИНА     1931     ЯЦЫК    0.600000
#
# [11592 rows x 4 columns]

# %%
# Number of unique document patterns in fact_data
a = fact_data[["document"]].drop_duplicates().dropna()
a
# Out:
#            document
# 0          AP!!!!!!
# 1         AB!!!!!!!
# 2         СР!!!!!!!
# 5           !!!!!!!
# 6        !!!!!!!!!!
# ...             ...
# 9281   PKGZAC!!!!!!
# 9341      CH!!!!!!!
# 9397      !!!!!!!СО
# 9471  PUZBCB!!!!!!!
# 9499      СГ!!!!!!!
#
# [505 rows x 1 columns]

# %%
# Number of unique document patterns in test_data
a = test_data[["document"]].drop_duplicates().dropna()
a
# Out:
#          document
# 0        С!!!!!!!
# 1      !!!!!!!!!!
# 3        З!!!!!!!
# 6         С!!!!!!
# 7        P!!!!!!!
# ...           ...
# 2405    АН!!!!!!!
# 2413     ET!!!!!!
# 2441    CO!!!!!!!
# 2447  VIIМЮ!!!!!!
# 2468   I-ВВ!!!!!!
#
# [272 rows x 1 columns]

# %%
# Patterns from test_data not present in fact_data
a = test_data[["document"]].drop_duplicates().dropna()
b = fact_data["document"].dropna().unique()
a[~a["document"].isin(b)]
# Out:
#            document
# 3          З!!!!!!!
# 27       СК!!!!!!!!
# 33       IIСТ!!!!!!
# 127       АФ!!!!!!!
# 164        FU!!!!!!
# 179       Р!!!!!!!!
# 212       ARM!!!!!!
# 326       РC!!!!!!!
# 330      PPP!!!!!!!
# 358      AZEC!!!!!!
# 361        АP!!!!!!
# 400      IРХ!!!!!!!
# 472       SMI!!!!!!
# 485        MA!!!!!!
# 492       АC!!!!!!!
# 524      I-БП!!!!!!
# 688       АКО!!!!!!
# 730      AC!!!!!!!!
# 752    PCAZEC!!!!!!
# 757        IV!!!!!!
# 758      I-ФП!!!!!!
# 813       IИД!!!!!!
# 893      !АС!!!!!!!
# 911       IКЕ!!!!!!
# 915       IМР!!!!!!
# 968        !КЕ!!!!!
# 998       IТН!!!!!!
# 1045     АА!!!!!!!!
# 1120       CB!!!!!!
# 1164       FL!!!!!!
# 1219      KM!!!!!!!
# 1230  PUZBCS!!!!!!!
# 1244      VКН!!!!!!
# 1252  AZEC!!!!!!!!!
# 1314       CA!!!!!!
# 1332      FRI!!!!!!
# 1367  PCAZEС!!!!!!!
# 1446     IIЕА!!!!!!
# 1514    IIIИК!!!!!!
# 1523      МО!!!!!!!
# 1558      III!!!!!!
# 1584    IIIПО!!!!!!
# 1669    ARMAM!!!!!!
# 1696     !!N!!!!!!!
# 1742       !ВЛ!!!!!
# 1774     АК!!!!!!!!
# 1822       РМ!!!!!!
# 1868    AZEC!!!!!!!
# 1905      PAN!!!!!!
# 1927      ИД!!!!!!!
# 1928     PC!!!!!!!!
# 1995  РРAZEP!!!!!!!
# 1998       EO!!!!!!
# 2042      IНР!!!!!!
# 2062     СС!!!!!!!!
# 2208     IVАИ!!!!!!
# 2224   ППАЗЕ!!!!!!!
# 2225      IP!!!!!!!

# %%
a = fact_data[["document", "country"]].drop_duplicates().dropna()
a.loc[:, "doc_alpha"] = a["document"].str.replace(r"\!+", "")

b = test_data[["document"]].drop_duplicates().dropna()
b.loc[:, "doc_alpha"] = b["document"].str.replace(r"\!+", "")
a
# Out:
# /tmp/ipykernel_213199/694234592.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   a.loc[:, "doc_alpha"] = a["document"].str.replace(r"\!+", "")
# /tmp/ipykernel_213199/694234592.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   b.loc[:, "doc_alpha"] = b["document"].str.replace(r"\!+", "")
#            document      country doc_alpha
# 0          AP!!!!!!      АРМЕНИЯ        AP
# 1         AB!!!!!!!   УЗБЕКИСТАН        AB
# 2         СР!!!!!!!   УЗБЕКИСТАН        СР
# 5           !!!!!!!     КИРГИЗИЯ
# 6        !!!!!!!!!!       РОССИЯ
# ...             ...          ...       ...
# 9341      CH!!!!!!!   УЗБЕКИСТАН        CH
# 9397      !!!!!!!СО  АЗЕРБАЙДЖАН        СО
# 9448      VИК!!!!!!  АЗЕРБАЙДЖАН       VИК
# 9471  PUZBCB!!!!!!!   УЗБЕКИСТАН    PUZBCB
# 9499      СГ!!!!!!!   УЗБЕКИСТАН        СГ
#
# [622 rows x 3 columns]

# %%
unq_doc_lookup[unq_doc_lookup["document"]=="APMBA!!!!!!!" ]
# Out:
#          document  country
# 343  APMBA!!!!!!!  АРМЕНИЯ

# %%
a = test_data[test_data["document"].isin(unq_doc_lookup["document"])].copy()
a = a.drop(columns="country")
pd.merge(a, unq_doc_lookup)
# Out:
#                                 name gender     document      name0     name1  \
# 0        АББАСОВ ЭЛЬФАГ ИБРАГИМ ОГЛЫ   None    P!!!!!!!!    АББАСОВ    ЭЛЬФАГ
# 1           АБГАРЯН ДИАНА АРКАДЬЕВНА   None     AR!!!!!!    АБГАРЯН     ДИАНА
# 2               АЙРОЯН ГЕВОРГ ЭДУАРД   None     AR!!!!!!     АЙРОЯН    ГЕВОРГ
# 3           АМРОЯН КАДЖИК ГЕВОРГОВИЧ   None     AR!!!!!!     АМРОЯН    КАДЖИК
# 4             АНИСЯН АНАИТ КОРЮНОВНА   None     AR!!!!!!     АНИСЯН     АНАИТ
# ..                               ...    ...          ...        ...       ...
# 563  ЧЕРШУКОВА АНЖЕЛИКА ВЛАДИМИРОВНА   None   АВ!!!!!!!!  ЧЕРШУКОВА  АНЖЕЛИКА
# 564          ШИТОВА ОЛЬГА ВАСИЛЬЕВНА   None     ET!!!!!!     ШИТОВА     ОЛЬГА
# 565     ЭВАЙЗОВ АДИЛ ТАНРЫВЕРДИ ОГЛЫ   None    CO!!!!!!!    ЭВАЙЗОВ      АДИЛ
# 566      ЭЙВАЗОВА СААДАТ ЭЛЬЧИН КЫЗЫ   None  VIIМЮ!!!!!!   ЭЙВАЗОВА    СААДАТ
# 567                     ЮДИНА ПОЛИНА   None   I-ВВ!!!!!!      ЮДИНА    ПОЛИНА
#
#             name2 name3 name4 name5      country
# 0         ИБРАГИМ  ОГЛЫ  None  None       РОССИЯ
# 1      АРКАДЬЕВНА  None  None  None      АРМЕНИЯ
# 2          ЭДУАРД  None  None  None      АРМЕНИЯ
# 3      ГЕВОРГОВИЧ  None  None  None      АРМЕНИЯ
# 4       КОРЮНОВНА  None  None  None      АРМЕНИЯ
# ..            ...   ...   ...   ...          ...
# 563  ВЛАДИМИРОВНА  None  None  None   УЗБЕКИСТАН
# 564    ВАСИЛЬЕВНА  None  None  None      УКРАИНА
# 565    ТАНРЫВЕРДИ  ОГЛЫ  None  None  АЗЕРБАЙДЖАН
# 566        ЭЛЬЧИН  КЫЗЫ  None  None       РОССИЯ
# 567          None  None  None  None      УКРАИНА
#
# [568 rows x 10 columns]

# %%
docs = fact_data[["document", "country"]].copy().dropna()
docs.loc[:, "doc_len"] = docs["document"].str.len()
a = docs[["country", "doc_len"]].drop_duplicates()
a.groupby("country").describe()
# Out:
#             doc_len
#               count    mean       std  min   25%   50%    75%   max
# country
# АЗЕРБАЙДЖАН     9.0  10.000  2.738613  6.0  8.00  10.0  12.00  14.0
# АРМЕНИЯ         8.0   9.500  2.449490  6.0  7.75   9.5  11.25  13.0
# КИРГИЗИЯ        7.0   9.000  2.160247  6.0  7.50   9.0  10.50  12.0
# РОССИЯ          7.0   9.000  2.160247  6.0  7.50   9.0  10.50  12.0
# УЗБЕКИСТАН      8.0   9.875  2.900123  6.0  7.75   9.5  12.25  14.0
# УКРАИНА         6.0   8.500  1.870829  6.0  7.25   8.5   9.75  11.0

# %% [markdown]
# Сколько уникальных фамилий из фактического списка "двойного" пола присутствуют в тестовом датасете:

# %%
l = 12
a = docs.loc[docs["doc_len"]==l][["country", "document"]].drop_duplicates()
#unq_doc_lookup[unq_doc_lookup["document"].str.len()==l]
a[~(a["document"].isin(unq_doc_lookup["document"]))]
# Out:
#        country      document
# 2408    РОССИЯ  VIIIМЮ!!!!!!
# 9115  КИРГИЗИЯ  VIIIМЮ!!!!!!

# %%
test_docs = test_data[["document"]].copy().dropna()
test_docs.loc[:, "doc_len"] = test_docs["document"].str.len()
pd.merge(test_docs[test_docs["doc_len"]==12], unq_doc_lookup)
# Out:
#        document  doc_len      country
# 0  PPAZE!!!!!!!       12  АЗЕРБАЙДЖАН

# %% [markdown]
# Присвоим пол по фамилии там где это возможно.

# %%
gender_by_name0 = fact_data[["name0", "gender"]].drop_duplicates()
gender_by_name0 = gender_by_name0[~gender_by_name0["name0"].isin(twin_gender["name0"])]
a = test_data.copy()
a = a.drop(columns="gender")
gendered_by_name0 = pd.merge(a, gender_by_name0, on="name0")

# %%
a = fact_data[["name1", "gender"]].drop_duplicates()
a = a.dropna()
a = a.groupby("name1").count().reset_index()
twin_gender_name1 = a[a["gender"]>1]
twin_gender_name1
# Out:
#          name1  gender
# 203      АЙСУН       2
# 211      АЙХАН       2
# 390       АРЗУ       2
# 431   АРШАЛУЙС       2
# 848   ГУЛЬНАРА       2
# 882     ГЮНЕЛЬ       2
# 909     ДАНИИЛ       2
# 1188    ЗИЯФАТ       2
# 1454      КЫЗЫ       2
# 1720    МИХАИЛ       2
# 1827    НАГИМА       2
# 1898   НАТАЛЬЯ       2
# 2100    ПАРВИН       2
# 2303   САЛАМАТ       2
# 2402      СЕМА       2
# 2497   СУСАННА       2
# 2632    УЛЬФАТ       2
# 2849    ЧЫНГЫЗ       2

# %%
fact_data[fact_data["name1"]=="МИХАИЛ"]
# Out:
#                                 name gender     document      country  \
# 244         АБЕЛОВ МИХАИЛ ВАЛЕРЬЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 281      АБЬЮСЕЙХО МИХАИЛ ЕВГЕНЬЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 432            АДЫЕВ МИХАИЛ ИВАНОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 642    АЛЕКСАНДРОВ МИХАИЛ ДМИТРИЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 961       АРАКЕЛЯН МИХАИЛ РОБЕРТОВИЧ      М     АН!!!!!!      АРМЕНИЯ
# 1351        БАБКИН МИХАИЛ ТИМОФЕЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 1555         БАШУК МИХАИЛ АЛЕКСЕЕВИЧ      М         None      УКРАИНА
# 1635    БЕЛЯКОВ МИХАИЛ ЗЕЙНУЛЛА ОГЛЫ      М   !!!!!!!!!!       РОССИЯ
# 1683      БИТЬКО МИХАИЛ ВЛАДИМИРОВНА      Ж     ВУ!!!!!!      УКРАИНА
# 1789          БРАЖКО МИХАИЛ ПАВЛОВИЧ      М     СЮ!!!!!!      УКРАИНА
# 2312          ГАУН МИХАИЛ НИКОЛАЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 2588             ГРИДИН МИХАИЛ ИЛЬИЧ      М   !!!!!!!!!!       РОССИЯ
# 2638        ГУЛИЕВ МИХАИЛ ЕВГЕНЬЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 2849      ДАУРБЕКОВ МИХАИЛ РАМИСОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 3041      ДМИТРИЕВ МИХАИЛ НИКОЛАЕВИЧ      М  VIIИК!!!!!!       РОССИЯ
# 3084         ДОЧИНЕЦ МИХАИЛ ИВАНОВИЧ      М     ВО!!!!!!      УКРАИНА
# 3251       ЕФРЕМОВ МИХАИЛ ВИКТОРОВИЧ      М     ВУ!!!!!!      УКРАИНА
# 3261      ЖАКСЫБАЙ МИХАИЛ ВАСИЛЬЕВИЧ      М    VАИ!!!!!!       РОССИЯ
# 3304        ЖГИЛЕВ МИХАИЛ ЕВГЕНЬЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 3474                  ЗАХАРОВ МИХАИЛ      М     НЮ!!!!!!      УКРАИНА
# 3591        ИБРАГИМОВ МИХАИЛ ЮРЬЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 3945     КАЗЬМИР МИХАИЛ ВЛАДИМИРОВИЧ      М     EP!!!!!!      УКРАИНА
# 4328                    КОЗЯР МИХАИЛ      М     КВ!!!!!!      УКРАИНА
# 4382         КОНОВ МИХАИЛ НИКОЛАЕВИЧ      М     ВУ!!!!!!      УКРАИНА
# 4414       КОРОЛЕВ МИХАИЛ ВАСИЛЬЕВИЧ      М    !HO!!!!!!      УКРАИНА
# 4450  КОСТИЦКИЙ МИХАИЛ АЛЕКСАНДРОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 4513               КРИВОПИШИН МИХАИЛ      М   !!!!!!!!!!      УКРАИНА
# 4803           ЛУКИН МИХАИЛ ИГОРЕВИЧ      М     КА!!!!!!      УКРАИНА
# 4898        МАКАРОВ МИХАИЛ АНДРЕЕВИЧ      М   VIИК!!!!!!       РОССИЯ
# 4903   МАКЕЕНОК МИХАИЛ АЛЕКСАНДРОВИЧ      М      !!!!!!!       РОССИЯ
# 5055      МАМЕДОВ МИХАИЛ НИЗАМИ ОГЛЫ      М      C!!!!!!  АЗЕРБАЙДЖАН
# 5273      МАРТЫНЮК МИХАИЛ ВИКТОРОВИЧ      М         None      УКРАИНА
# 5568      МИХЕЙКИН МИХАИЛ МИХАЙЛОВИЧ      М     СР!!!!!!      УКРАИНА
# 6150        НУРМАТОВ МИХАИЛ ИВАНОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 6188         ОВСЕПЯН МИХАИЛ АШОТОВИЧ      М   !!!!!!!!!!      АРМЕНИЯ
# 6665      ПОСКАЛОВ МИХАИЛ АЛЕКСЕЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 6690   ПРОЗАПАС МИХАИЛ АЛЕКСАНДРОВИЧ      М    !!!!!!!!!      УКРАИНА
# 6692    ПРОКОПОВИЧ МИХАИЛ ВАСИЛЬЕВИЧ      М     МК!!!!!!      УКРАИНА
# 6715          ПРЯТКИН МИХАИЛ ЮРЬЕВИЧ      М     ЕМ!!!!!!      УКРАИНА
# 6881          РЕВА МИХАИЛ НИКОЛАЕВИЧ      М         None      УКРАИНА
# 6969         РУБАН МИХАИЛ ВИКТОРОВИЧ      М     КА!!!!!!      УКРАИНА
# 7002    РУКАВИЧКИН МИХАИЛ АЛЕКСЕЕВИЧ      М   !!!!!!!!!!       РОССИЯ
# 7690                    СУКОВ МИХАИЛ      М     FE!!!!!!      УКРАИНА
# 8207       ТЫКВА МИХАИЛ ВЛАДИМИРОВИЧ      М     ER!!!!!!      УКРАИНА
# 8263        УНГУЛ МИХАИЛ АНАТОЛЬЕВИЧ      М   !!!!!!!!!!      УКРАИНА
# 8360         ФАСТ МИХАИЛ ЭШМАХАТОВИЧ      М    !!!!!!!!!       РОССИЯ
# 8679      ХОАНГ МИХАИЛ АЛЕКСАНДРОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 8753          ХРОЯН МИХАИЛ АХМЕДОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 8823           ЦАП МИХАИЛ ГЕОРГИЕВИЧ      М   !!!!!!!!!!      УКРАИНА
# 8824           ЦАП МИХАИЛ НИКОЛАЕВИЧ      М     КЕ!!!!!!      УКРАИНА
# 8853                    ЧЕКИН МИХАИЛ      М         None      УКРАИНА
# 9036            ШАРОВ МИХАИЛ ЮРЬЕВИЧ      М    VАР!!!!!!       РОССИЯ
# 9156      ШКАРУПИЛО МИХАИЛ РОМАНОВИЧ      М         None      УКРАИНА
# 9211     ШУЛЬЖЕНКО МИХАИЛ РУСТАМОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 9221           ШУРОВ МИХАИЛ ДАУДОВИЧ      М   !!!!!!!!!!       РОССИЯ
# 9263      ЭЙТНЕР МИХАИЛ ВЛАДИМИРОВИЧ      М   !!!!!!!!!!       РОССИЯ
#
#             name0   name1          name2 name3 name4 name5
# 244        АБЕЛОВ  МИХАИЛ     ВАЛЕРЬЕВИЧ  None  None  None
# 281     АБЬЮСЕЙХО  МИХАИЛ     ЕВГЕНЬЕВИЧ  None  None  None
# 432         АДЫЕВ  МИХАИЛ       ИВАНОВИЧ  None  None  None
# 642   АЛЕКСАНДРОВ  МИХАИЛ     ДМИТРИЕВИЧ  None  None  None
# 961      АРАКЕЛЯН  МИХАИЛ     РОБЕРТОВИЧ  None  None  None
# 1351       БАБКИН  МИХАИЛ     ТИМОФЕЕВИЧ  None  None  None
# 1555        БАШУК  МИХАИЛ     АЛЕКСЕЕВИЧ  None  None  None
# 1635      БЕЛЯКОВ  МИХАИЛ       ЗЕЙНУЛЛА  ОГЛЫ  None  None
# 1683       БИТЬКО  МИХАИЛ   ВЛАДИМИРОВНА  None  None  None
# 1789       БРАЖКО  МИХАИЛ       ПАВЛОВИЧ  None  None  None
# 2312         ГАУН  МИХАИЛ     НИКОЛАЕВИЧ  None  None  None
# 2588       ГРИДИН  МИХАИЛ          ИЛЬИЧ  None  None  None
# 2638       ГУЛИЕВ  МИХАИЛ     ЕВГЕНЬЕВИЧ  None  None  None
# 2849    ДАУРБЕКОВ  МИХАИЛ      РАМИСОВИЧ  None  None  None
# 3041     ДМИТРИЕВ  МИХАИЛ     НИКОЛАЕВИЧ  None  None  None
# 3084      ДОЧИНЕЦ  МИХАИЛ       ИВАНОВИЧ  None  None  None
# 3251      ЕФРЕМОВ  МИХАИЛ     ВИКТОРОВИЧ  None  None  None
# 3261     ЖАКСЫБАЙ  МИХАИЛ     ВАСИЛЬЕВИЧ  None  None  None
# 3304       ЖГИЛЕВ  МИХАИЛ     ЕВГЕНЬЕВИЧ  None  None  None
# 3474      ЗАХАРОВ  МИХАИЛ           None  None  None  None
# 3591    ИБРАГИМОВ  МИХАИЛ        ЮРЬЕВИЧ  None  None  None
# 3945      КАЗЬМИР  МИХАИЛ   ВЛАДИМИРОВИЧ  None  None  None
# 4328        КОЗЯР  МИХАИЛ           None  None  None  None
# 4382        КОНОВ  МИХАИЛ     НИКОЛАЕВИЧ  None  None  None
# 4414      КОРОЛЕВ  МИХАИЛ     ВАСИЛЬЕВИЧ  None  None  None
# 4450    КОСТИЦКИЙ  МИХАИЛ  АЛЕКСАНДРОВИЧ  None  None  None
# 4513   КРИВОПИШИН  МИХАИЛ           None  None  None  None
# 4803        ЛУКИН  МИХАИЛ       ИГОРЕВИЧ  None  None  None
# 4898      МАКАРОВ  МИХАИЛ      АНДРЕЕВИЧ  None  None  None
# 4903     МАКЕЕНОК  МИХАИЛ  АЛЕКСАНДРОВИЧ  None  None  None
# 5055      МАМЕДОВ  МИХАИЛ         НИЗАМИ  ОГЛЫ  None  None
# 5273     МАРТЫНЮК  МИХАИЛ     ВИКТОРОВИЧ  None  None  None
# 5568     МИХЕЙКИН  МИХАИЛ     МИХАЙЛОВИЧ  None  None  None
# 6150     НУРМАТОВ  МИХАИЛ       ИВАНОВИЧ  None  None  None
# 6188      ОВСЕПЯН  МИХАИЛ       АШОТОВИЧ  None  None  None
# 6665     ПОСКАЛОВ  МИХАИЛ     АЛЕКСЕЕВИЧ  None  None  None
# 6690     ПРОЗАПАС  МИХАИЛ  АЛЕКСАНДРОВИЧ  None  None  None
# 6692   ПРОКОПОВИЧ  МИХАИЛ     ВАСИЛЬЕВИЧ  None  None  None
# 6715      ПРЯТКИН  МИХАИЛ        ЮРЬЕВИЧ  None  None  None
# 6881         РЕВА  МИХАИЛ     НИКОЛАЕВИЧ  None  None  None
# 6969        РУБАН  МИХАИЛ     ВИКТОРОВИЧ  None  None  None
# 7002   РУКАВИЧКИН  МИХАИЛ     АЛЕКСЕЕВИЧ  None  None  None
# 7690        СУКОВ  МИХАИЛ           None  None  None  None
# 8207        ТЫКВА  МИХАИЛ   ВЛАДИМИРОВИЧ  None  None  None
# 8263        УНГУЛ  МИХАИЛ    АНАТОЛЬЕВИЧ  None  None  None
# 8360         ФАСТ  МИХАИЛ    ЭШМАХАТОВИЧ  None  None  None
# 8679        ХОАНГ  МИХАИЛ  АЛЕКСАНДРОВИЧ  None  None  None
# 8753        ХРОЯН  МИХАИЛ      АХМЕДОВИЧ  None  None  None
# 8823          ЦАП  МИХАИЛ     ГЕОРГИЕВИЧ  None  None  None
# 8824          ЦАП  МИХАИЛ     НИКОЛАЕВИЧ  None  None  None
# 8853        ЧЕКИН  МИХАИЛ           None  None  None  None
# 9036        ШАРОВ  МИХАИЛ        ЮРЬЕВИЧ  None  None  None
# 9156    ШКАРУПИЛО  МИХАИЛ      РОМАНОВИЧ  None  None  None
# 9211    ШУЛЬЖЕНКО  МИХАИЛ     РУСТАМОВИЧ  None  None  None
# 9221        ШУРОВ  МИХАИЛ       ДАУДОВИЧ  None  None  None
# 9263       ЭЙТНЕР  МИХАИЛ   ВЛАДИМИРОВИЧ  None  None  None

# %%
b = test_data.copy()
b.loc[:, "two_names"] = b["name0"] + b["name1"]

len(set(b["two_names"]) - set(a["two_names"]))
# Out:
# 2433

# %%
fact_data[fact_data["name0"]=="ЩЕРБАК"]
# Out:
#                           name gender    document  country   name0    name1  \
# 9234  ЩЕРБАК АНДРЕЙ АЛЕКСЕЕВИЧ      М  !!!!!!!!!!   РОССИЯ  ЩЕРБАК   АНДРЕЙ
# 9235   ЩЕРБАК ДЖУЛЕТА ВРЕЖОВНА      Ж  !!!!!!!!!!  АРМЕНИЯ  ЩЕРБАК  ДЖУЛЕТА
# 9236   ЩЕРБАК МЕЛИК НИКОЛАЕВИЧ      М  !!!!!!!!!!  УКРАИНА  ЩЕРБАК    МЕЛИК
#
#            name2 name3 name4 name5
# 9234  АЛЕКСЕЕВИЧ  None  None  None
# 9235    ВРЕЖОВНА  None  None  None
# 9236  НИКОЛАЕВИЧ  None  None  None
